# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

#page number
page_number = 0
# Build URL
query_url =(
    'https://api.nytimes.com/svc/search/v2/articlesearch.json?' + #query string starts with a'?
    f'api-key={nyt_api_key}' + #parameter name = paramater value
    f'&end_date={end_date}' +
    f'&fq={filter_query}' +
    f'&sort={sort}' +
    f'&fl={field_list}' +
    f'&begin_date={begin_date}' + # '&' is the query seperator
    f'&page={str(page_number)}'
)

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(20):
    # create query with a page number
    query_url =(
    'https://api.nytimes.com/svc/search/v2/articlesearch.json?' + #query string starts with a'?
    f'api-key={nyt_api_key}' + #parameter name = paramater value
    f'&end_date={end_date}' +
    f'&fq={filter_query}' +
    f'&sort={sort}' +
    f'&fl={field_list}' +
    f'&begin_date={begin_date}' + # '&' is the query seperator
    f'&page={str(page_number)}'
    )
    # API results show 10 articles at a time    
    
    # Make a "GET" request and retrieve the JSON
    response = requests.get(query_url)
    reviews = response.json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:            
        # loop through the reviews["response"]["docs"] and append each review to the list
        for doc in reviews["response"]["docs"]:
            reviews_list.append(doc)       
            
        # Print the page that was just retrieved
        print(f"Checked page {page + 1}")
        
        # Print the page number that had no results then break from the loop
    except KeyError:
        print(f"Error on {page + 1}")
        break
# Out:
# Checked page 1
# Checked page 2
# Checked page 3
# Checked page 4
# Checked page 5
# Checked page 6
# Checked page 7
# Checked page 8
# Checked page 9
# Checked page 10
# Checked page 11
# Checked page 12
# Checked page 13
# Checked page 14
# Checked page 15
# Checked page 16
# Checked page 17
# Checked page 18
# Checked page 19
# Checked page 20

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5],indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
df_reviews = pd.json_normalize(reviews_list)
df_reviews
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2023/04/13/movies/one-...
# 196  https://www.nytimes.com/2023/04/13/movies/the-...
# 197  https://www.nytimes.com/2023/03/30/movies/a-th...
# 198  https://www.nytimes.com/2023/02/09/movies/your...
# 199  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 196  There’s not much Lennon music heard in this do...  The New York Times
# 197  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 198  This humdrum Netflix romantic comedy features ...  The New York Times
# 199  To combat the overdose crisis, a group that in...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Documentary Fil...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'subject', 'value': 'Documentary Fil...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2023-04-13T11:00:06+0000         320
# 196  2023-04-13T11:00:03+0000         327
# 197  2023-03-30T18:53:42+0000         971
# 198  2023-02-10T00:00:05+0000         569
# 199  2023-02-02T12:00:11+0000         306
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 196  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 197  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# 198           ‘Your Place or Mine’ Review: Try Neither            None
# 199  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#     headline.content_kicker                  headline.print_headline  \
# 0                      None                   The Attachment Diaries
# 1                      None           What’s Love Got to Do With It?
# 2                      None                     You Can Live Forever
# 3                      None               A Tourist’s  Guide to Love
# 4                      None   Intoxicating Love With a Sobering Turn
# ..                      ...                                      ...
# 195                    None                           One True Loves
# 196                    None          The Lost Weekend:  A Love Story
# 197                    None  An Unbending Will Meets a Shifting City
# 198                    None         They Have a Humdrum Kind of Love
# 199                    None             Love in the Time Of Fentanyl
#
#     headline.name headline.seo headline.sub           byline.original  \
# 0            None         None         None    By Jeannette Catsoulis
# 1            None         None         None    By Jeannette Catsoulis
# 2            None         None         None  By Elisabeth Vincentelli
# 3            None         None         None  By Elisabeth Vincentelli
# 4            None         None         None         By Manohla Dargis
# ..            ...          ...          ...                       ...
# 195          None         None         None             By Brandon Yu
# 196          None         None         None            By Glenn Kenny
# 197          None         None         None         By Manohla Dargis
# 198          None         None         None          By Amy Nicholson
# 199          None         None         None     By Concepción de León
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 196  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 198  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 199  [{'firstname': 'Concepción', 'middlename': Non...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
df_reviews['title'] = df_reviews['headline.main'].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
df_reviews
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2023/04/13/movies/one-...
# 196  https://www.nytimes.com/2023/04/13/movies/the-...
# 197  https://www.nytimes.com/2023/03/30/movies/a-th...
# 198  https://www.nytimes.com/2023/02/09/movies/your...
# 199  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 196  There’s not much Lennon music heard in this do...  The New York Times
# 197  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 198  This humdrum Netflix romantic comedy features ...  The New York Times
# 199  To combat the overdose crisis, a group that in...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Documentary Fil...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'subject', 'value': 'Documentary Fil...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2023-04-13T11:00:06+0000         320
# 196  2023-04-13T11:00:03+0000         327
# 197  2023-03-30T18:53:42+0000         971
# 198  2023-02-10T00:00:05+0000         569
# 199  2023-02-02T12:00:11+0000         306
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 196  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 197  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# 198           ‘Your Place or Mine’ Review: Try Neither            None
# 199  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#     headline.content_kicker                  headline.print_headline  \
# 0                      None                   The Attachment Diaries
# 1                      None           What’s Love Got to Do With It?
# 2                      None                     You Can Live Forever
# 3                      None               A Tourist’s  Guide to Love
# 4                      None   Intoxicating Love With a Sobering Turn
# ..                      ...                                      ...
# 195                    None                           One True Loves
# 196                    None          The Lost Weekend:  A Love Story
# 197                    None  An Unbending Will Meets a Shifting City
# 198                    None         They Have a Humdrum Kind of Love
# 199                    None             Love in the Time Of Fentanyl
#
#     headline.name headline.seo headline.sub           byline.original  \
# 0            None         None         None    By Jeannette Catsoulis
# 1            None         None         None    By Jeannette Catsoulis
# 2            None         None         None  By Elisabeth Vincentelli
# 3            None         None         None  By Elisabeth Vincentelli
# 4            None         None         None         By Manohla Dargis
# ..            ...          ...          ...                       ...
# 195          None         None         None             By Brandon Yu
# 196          None         None         None            By Glenn Kenny
# 197          None         None         None         By Manohla Dargis
# 198          None         None         None          By Amy Nicholson
# 199          None         None         None     By Concepción de León
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 196  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 198  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 199  [{'firstname': 'Concepción', 'middlename': Non...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 195                                 One True Loves
# 196                 The Lost Weekend: A Love Story
# 197                             A Thousand and One
# 198                             Your Place or Mine
# 199                   Love in the Time of Fentanyl
#
# [200 rows x 17 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
df_reviews['keywords'] = df_reviews['keywords'].apply(extract_keywords)
df_reviews
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2023/04/13/movies/one-...
# 196  https://www.nytimes.com/2023/04/13/movies/the-...
# 197  https://www.nytimes.com/2023/03/30/movies/a-th...
# 198  https://www.nytimes.com/2023/02/09/movies/your...
# 199  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 196  There’s not much Lennon music heard in this do...  The New York Times
# 197  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
# 198  This humdrum Netflix romantic comedy features ...  The New York Times
# 199  To combat the overdose crisis, a group that in...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;persons: Kapur, Shekhar;person...
# 2    subject: Movies;creative_works: You Can Live F...
# 3    subject: Movies;creative_works: A Tourist's Gu...
# 4    subject: Movies;persons: Zlotowski, Rebecca;cr...
# ..                                                 ...
# 195  subject: Movies;persons: Bracey, Luke (1989- )...
# 196  subject: Documentary Films and Programs;creati...
# 197  subject: Movies;creative_works: A Thousand and...
# 198  subject: Movies;creative_works: Your Place or ...
# 199  subject: Documentary Films and Programs;subjec...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2023-04-13T11:00:06+0000         320
# 196  2023-04-13T11:00:03+0000         327
# 197  2023-03-30T18:53:42+0000         971
# 198  2023-02-10T00:00:05+0000         569
# 199  2023-02-02T12:00:11+0000         306
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 196  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 197  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# 198           ‘Your Place or Mine’ Review: Try Neither            None
# 199  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#     headline.content_kicker                  headline.print_headline  \
# 0                      None                   The Attachment Diaries
# 1                      None           What’s Love Got to Do With It?
# 2                      None                     You Can Live Forever
# 3                      None               A Tourist’s  Guide to Love
# 4                      None   Intoxicating Love With a Sobering Turn
# ..                      ...                                      ...
# 195                    None                           One True Loves
# 196                    None          The Lost Weekend:  A Love Story
# 197                    None  An Unbending Will Meets a Shifting City
# 198                    None         They Have a Humdrum Kind of Love
# 199                    None             Love in the Time Of Fentanyl
#
#     headline.name headline.seo headline.sub           byline.original  \
# 0            None         None         None    By Jeannette Catsoulis
# 1            None         None         None    By Jeannette Catsoulis
# 2            None         None         None  By Elisabeth Vincentelli
# 3            None         None         None  By Elisabeth Vincentelli
# 4            None         None         None         By Manohla Dargis
# ..            ...          ...          ...                       ...
# 195          None         None         None             By Brandon Yu
# 196          None         None         None            By Glenn Kenny
# 197          None         None         None         By Manohla Dargis
# 198          None         None         None          By Amy Nicholson
# 199          None         None         None     By Concepción de León
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 196  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Manohla', 'middlename': None, ...                None
# 198  [{'firstname': 'Amy', 'middlename': None, 'las...                None
# 199  [{'firstname': 'Concepción', 'middlename': Non...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 195                                 One True Loves
# 196                 The Lost Weekend: A Love Story
# 197                             A Thousand and One
# 198                             Your Place or Mine
# 199                   Love in the Time of Fentanyl
#
# [200 rows x 17 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = df_reviews['title'].to_list()
titles
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
for title in titles:
    
        # Perform a "GET" request for The Movie Database
        tmdb_search_url = url + title.replace(" ", "+") + tmdb_key_string
        tmdb_search_response = requests.get(tmdb_search_url)
        tmdb_search_results = tmdb_search_response.json()

        # Include a try clause to search for the full movie details.
        # Use the except clause to print out a statement if a movie
        # is not found.
        try:
            # Get movie id
            movie_id = tmdb_search_results['results'][0]['id']

            # Make a request for a the full movie details
            tmdb_movie_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"
            tmdb_movie_response = requests.get(tmdb_movie_url)
            tmdb_movie_details = tmdb_movie_response.json()

            # Execute "GET" request with url

            # Extract the genre names into a list
            genres = [genre['name'] for genre in tmdb_movie_details['genres']]
            spoken_languages = [lang['english_name'] for lang in tmdb_movie_details['spoken_languages']]
            production_countries = [country['name'] for country in tmdb_movie_details['production_countries']]

            # Extract the spoken_languages' English name into a list
            spoken_languages = [lang['english_name'] for lang in tmdb_movie_details['spoken_languages']]


            # Extract the production_countries' name into a list
            production_countries = [country['name'] for country in tmdb_movie_details['production_countries']]


            # Add the relevant data to a dictionary and
            movie_dict = {
                'title': tmdb_movie_details['title'],
                'original_title': tmdb_movie_details['original_title'],
                'budget': tmdb_movie_details['budget'],
                'original_language': tmdb_movie_details['original_language'],
                'homepage': tmdb_movie_details['homepage'],
                'overview': tmdb_movie_details['overview'],
                'popularity': tmdb_movie_details['popularity'],
                'runtime': tmdb_movie_details['runtime'],
                'revenue': tmdb_movie_details['revenue'],
                'release_date': tmdb_movie_details['release_date'],
                'vote_average': tmdb_movie_details['vote_average'],
                'vote_count': tmdb_movie_details['vote_count'],
                'genres': genres,
                'spoken_languages': spoken_languages,
                'production_countries': production_countries
            }

            # append it to the tmdb_movies_list list
            tmdb_movies_list.append(movie_dict)

            # Print out the title that was found
            print(f"{tmdb_movie_details['title']} found.")
            request_counter += 1

        # Check if we need to sleep before making a request
            if request_counter % 50 == 0:
                time.sleep(1)
                print("Application is sleeping...")

        except IndexError:
                # Print a statement if movie is not found
            print(f"{title} not found.")
            request_counter += 1

        #except Exception as e:
            #print(f"Error processing title: {title}. Error: {e}")
# Out:
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Application is sleeping...
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Application is sleeping...
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Application is sleeping...
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Love in the Time of Fentanyl found.
# The Attachment Diaries found.
# What’s Love Got to Do With It?’ Probably a Lo not found.
# You Can Live Forever found.
# A Tourist's Guide to Love found.
# Other People's Children found.
# One True Loves found.
# The Lost Weekend: A Love Story found.
# A Thousand and One found.
# Your Place or Mine found.
# Application is sleeping...
# Love in the Time of Fentanyl found.

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "original_language": "es",
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 5.643,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 3.0,
#         "vote_count": 4,
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "production_countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "You Can Live Forever",
#         "original_title": "You Can Live Forever",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "popularity": 32.061,
#         "runtime": 96,
#         "revenue": 15055,
#         "release_date": "2023-03-24",
#         "vote_average": 6.7,
#         "vote_count": 33,
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "spoken_languages": [
#             "English",
#             "French"
#         ],
#         "production_countries": [
#             "Canada",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "A Tourist's Guide to Love",
#         "original_title": "A Tourist's Guide to Love",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://www.netflix.com/title/81424906",
#         "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#         "popularity": 17.444,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2023-04-21",
#         "vote_average": 6.3,
#         "vote_count": 158,
#         "genres": [
#             "Romance",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English",
#             "Vietnamese"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Other People's Children",
#         "original_title": "Les Enfants des autres",
#         "budget": 0,
#         "original_language": "fr",
#         "homepage": "https://www.wildbunch.biz/movie/other-peoples-children/",
#         "overview": "Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn\u2019t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?",
#         "popularity": 5.933,
#         "runtime": 104,
#         "revenue": 84178,
#         "release_date": "2022-09-21",
#         "vote_average": 6.842,
#         "vote_count": 184,
#         "genres": [
#             "Drama",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English",
#             "French"
#         ],
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "One True Loves",
#         "original_title": "One True Loves",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "",
#         "overview": "Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.",
#         "popularity": 13.177,
#         "runtime": 100,
#         "revenue": 37820,
#         "release_date": "2023-04-07",
#         "vote_average": 6.406,
#         "vote_count": 69,
#         "genres": [
#             "Romance",
#             "Drama",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English",
#             "Spanish"
#         ],
#         "production_countries": [
#             "Czech Republic",
#             "United States of America"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
tmdb_df
# Out:
#                               title                  original_title  budget  \
# 0            The Attachment Diaries                        El apego       0
# 1              You Can Live Forever            You Can Live Forever       0
# 2         A Tourist's Guide to Love       A Tourist's Guide to Love       0
# 3           Other People's Children          Les Enfants des autres       0
# 4                    One True Loves                  One True Loves       0
# ..                              ...                             ...     ...
# 175                  One True Loves                  One True Loves       0
# 176  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 177              A Thousand and One              A Thousand and One       0
# 178              Your Place or Mine              Your Place or Mine       0
# 179    Love in the Time of Fentanyl    Love in the Time of Fentanyl       0
#
#     original_language                                           homepage  \
# 0                  es
# 1                  en  https://gooddeedentertainment.com/you-can-live...
# 2                  en             https://www.netflix.com/title/81424906
# 3                  fr  https://www.wildbunch.biz/movie/other-peoples-...
# 4                  en
# ..                ...                                                ...
# 175                en
# 176                en                   https://thelostweekendmovie.com/
# 177                en  https://www.focusfeatures.com/a-thousand-and-one/
# 178                en             https://www.netflix.com/title/81045831
# 179                en
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       5.643      102
# 1    When Jaime, a gay teenager, is sent to live in...      32.061       96
# 2    After an unexpected break up, a travel executi...      17.444       96
# 3    Rachel loves her life, her students, her frien...       5.933      104
# 4    Emma and Jesse are living the perfect life tog...      13.177      100
# ..                                                 ...         ...      ...
# 175  Emma and Jesse are living the perfect life tog...      13.177      100
# 176  May Pang lovingly recounts her life in rock & ...       5.281       95
# 177  Struggling but unapologetically living on her ...      11.883      116
# 178  When best friends and total opposites Debbie a...      24.483      109
# 179  An intimate portrait of a community fighting t...       1.400       85
#
#      revenue release_date  vote_average  vote_count  \
# 0          0   2021-10-07         3.000           4
# 1      15055   2023-03-24         6.700          33
# 2          0   2023-04-21         6.300         158
# 3      84178   2022-09-21         6.842         184
# 4      37820   2023-04-07         6.406          69
# ..       ...          ...           ...         ...
# 175    37820   2023-04-07         6.406          69
# 176    77145   2023-04-13         6.000           2
# 177  3395595   2023-03-31         6.905          84
# 178        0   2023-02-10         6.275         696
# 179        0   2023-02-03         0.000           0
#
#                                  genres                spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]                       [Spanish]
# 1                      [Drama, Romance]               [English, French]
# 2                     [Romance, Comedy]           [English, Vietnamese]
# 3                       [Drama, Comedy]               [English, French]
# 4              [Romance, Drama, Comedy]              [English, Spanish]
# ..                                  ...                             ...
# 175            [Romance, Drama, Comedy]              [English, Spanish]
# 176                       [Documentary]                       [English]
# 177                      [Drama, Crime]  [English, Portuguese, Spanish]
# 178                   [Romance, Comedy]                       [English]
# 179                       [Documentary]                       [English]
#
#                            production_countries
# 0                                   [Argentina]
# 1            [Canada, United States of America]
# 2                    [United States of America]
# 3                                      [France]
# 4    [Czech Republic, United States of America]
# ..                                          ...
# 175  [Czech Republic, United States of America]
# 176                  [United States of America]
# 177                  [United States of America]
# 178                  [United States of America]
# 179          [Canada, United States of America]
#
# [180 rows x 15 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(df_reviews, tmdb_df, on='title', how='left')
merged_df
# Out:
#                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/the-...
# 1     https://www.nytimes.com/2023/05/25/movies/the-...
# 2     https://www.nytimes.com/2023/05/25/movies/the-...
# 3     https://www.nytimes.com/2023/05/25/movies/the-...
# 4     https://www.nytimes.com/2023/05/25/movies/the-...
# ...                                                 ...
# 2855  https://www.nytimes.com/2023/02/02/movies/love...
# 2856  https://www.nytimes.com/2023/02/02/movies/love...
# 2857  https://www.nytimes.com/2023/02/02/movies/love...
# 2858  https://www.nytimes.com/2023/02/02/movies/love...
# 2859  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                 snippet              source  \
# 0     A gynecologist and her patient form a horrifyi...  The New York Times
# 1     A gynecologist and her patient form a horrifyi...  The New York Times
# 2     A gynecologist and her patient form a horrifyi...  The New York Times
# 3     A gynecologist and her patient form a horrifyi...  The New York Times
# 4     A gynecologist and her patient form a horrifyi...  The New York Times
# ...                                                 ...                 ...
# 2855  To combat the overdose crisis, a group that in...  The New York Times
# 2856  To combat the overdose crisis, a group that in...  The New York Times
# 2857  To combat the overdose crisis, a group that in...  The New York Times
# 2858  To combat the overdose crisis, a group that in...  The New York Times
# 2859  To combat the overdose crisis, a group that in...  The New York Times
#
#                                                keywords  \
# 0     [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1     [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2     [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3     [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4     [{'name': 'subject', 'value': 'Movies', 'rank'...
# ...                                                 ...
# 2855  [{'name': 'subject', 'value': 'Documentary Fil...
# 2856  [{'name': 'subject', 'value': 'Documentary Fil...
# 2857  [{'name': 'subject', 'value': 'Documentary Fil...
# 2858  [{'name': 'subject', 'value': 'Documentary Fil...
# 2859  [{'name': 'subject', 'value': 'Documentary Fil...
#
#                       pub_date  word_count  \
# 0     2023-05-25T11:00:03+0000         295
# 1     2023-05-25T11:00:03+0000         295
# 2     2023-05-25T11:00:03+0000         295
# 3     2023-05-25T11:00:03+0000         295
# 4     2023-05-25T11:00:03+0000         295
# ...                        ...         ...
# 2855  2023-02-02T12:00:11+0000         306
# 2856  2023-02-02T12:00:11+0000         306
# 2857  2023-02-02T12:00:11+0000         306
# 2858  2023-02-02T12:00:11+0000         306
# 2859  2023-02-02T12:00:11+0000         306
#
#                                           headline.main headline.kicker  \
# 0           ‘The Attachment Diaries’ Review: Love, Sick            None
# 1           ‘The Attachment Diaries’ Review: Love, Sick            None
# 2           ‘The Attachment Diaries’ Review: Love, Sick            None
# 3           ‘The Attachment Diaries’ Review: Love, Sick            None
# 4           ‘The Attachment Diaries’ Review: Love, Sick            None
# ...                                                 ...             ...
# 2855  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2856  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2857  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2858  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2859  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#      headline.content_kicker       headline.print_headline  ...  \
# 0                       None        The Attachment Diaries  ...
# 1                       None        The Attachment Diaries  ...
# 2                       None        The Attachment Diaries  ...
# 3                       None        The Attachment Diaries  ...
# 4                       None        The Attachment Diaries  ...
# ...                      ...                           ...  ...
# 2855                    None  Love in the Time Of Fentanyl  ...
# 2856                    None  Love in the Time Of Fentanyl  ...
# 2857                    None  Love in the Time Of Fentanyl  ...
# 2858                    None  Love in the Time Of Fentanyl  ...
# 2859                    None  Love in the Time Of Fentanyl  ...
#
#                                                overview popularity runtime  \
# 0     Argentina, 1970s. A desperate young woman goes...      5.643   102.0
# 1     Argentina, 1970s. A desperate young woman goes...      5.643   102.0
# 2     Argentina, 1970s. A desperate young woman goes...      5.643   102.0
# 3     Argentina, 1970s. A desperate young woman goes...      5.643   102.0
# 4     Argentina, 1970s. A desperate young woman goes...      5.643   102.0
# ...                                                 ...        ...     ...
# 2855  An intimate portrait of a community fighting t...      1.400    85.0
# 2856  An intimate portrait of a community fighting t...      1.400    85.0
# 2857  An intimate portrait of a community fighting t...      1.400    85.0
# 2858  An intimate portrait of a community fighting t...      1.400    85.0
# 2859  An intimate portrait of a community fighting t...      1.400    85.0
#
#      revenue release_date vote_average vote_count  \
# 0        0.0   2021-10-07          3.0        4.0
# 1        0.0   2021-10-07          3.0        4.0
# 2        0.0   2021-10-07          3.0        4.0
# 3        0.0   2021-10-07          3.0        4.0
# 4        0.0   2021-10-07          3.0        4.0
# ...      ...          ...          ...        ...
# 2855     0.0   2023-02-03          0.0        0.0
# 2856     0.0   2023-02-03          0.0        0.0
# 2857     0.0   2023-02-03          0.0        0.0
# 2858     0.0   2023-02-03          0.0        0.0
# 2859     0.0   2023-02-03          0.0        0.0
#
#                                   genres  spoken_languages  \
# 0     [Drama, Mystery, Thriller, Horror]         [Spanish]
# 1     [Drama, Mystery, Thriller, Horror]         [Spanish]
# 2     [Drama, Mystery, Thriller, Horror]         [Spanish]
# 3     [Drama, Mystery, Thriller, Horror]         [Spanish]
# 4     [Drama, Mystery, Thriller, Horror]         [Spanish]
# ...                                  ...               ...
# 2855                       [Documentary]         [English]
# 2856                       [Documentary]         [English]
# 2857                       [Documentary]         [English]
# 2858                       [Documentary]         [English]
# 2859                       [Documentary]         [English]
#
#                     production_countries
# 0                            [Argentina]
# 1                            [Argentina]
# 2                            [Argentina]
# 3                            [Argentina]
# 4                            [Argentina]
# ...                                  ...
# 2855  [Canada, United States of America]
# 2856  [Canada, United States of America]
# 2857  [Canada, United States of America]
# 2858  [Canada, United States of America]
# 2859  [Canada, United States of America]
#
# [2860 rows x 31 columns]

# %%
   # Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ['keywords', 'genres', 'spoken_languages', 'production_countries']

# Create a list of characters to remove
characters_to_remove = ["[", "]", "'", '"']

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str'
    merged_df[column] = merged_df[column].astype(str)

    # Loop through characters to remove
    for char in characters_to_remove:
        merged_df[column] = merged_df[column].str.replace(char, '')

# Display the fixed DataFrame
print(merged_df)
# Out:
#                                                 web_url  \
# 0     https://www.nytimes.com/2023/05/25/movies/the-...
# 1     https://www.nytimes.com/2023/05/25/movies/the-...
# 2     https://www.nytimes.com/2023/05/25/movies/the-...
# 3     https://www.nytimes.com/2023/05/25/movies/the-...
# 4     https://www.nytimes.com/2023/05/25/movies/the-...
# ...                                                 ...
# 2855  https://www.nytimes.com/2023/02/02/movies/love...
# 2856  https://www.nytimes.com/2023/02/02/movies/love...
# 2857  https://www.nytimes.com/2023/02/02/movies/love...
# 2858  https://www.nytimes.com/2023/02/02/movies/love...
# 2859  https://www.nytimes.com/2023/02/02/movies/love...
#
#                                                 snippet              source  \
# 0     A gynecologist and her patient form a horrifyi...  The New York Times
# 1     A gynecologist and her patient form a horrifyi...  The New York Times
# 2     A gynecologist and her patient form a horrifyi...  The New York Times
# 3     A gynecologist and her patient form a horrifyi...  The New York Times
# 4     A gynecologist and her patient form a horrifyi...  The New York Times
# ...                                                 ...                 ...
# 2855  To combat the overdose crisis, a group that in...  The New York Times
# 2856  To combat the overdose crisis, a group that in...  The New York Times
# 2857  To combat the overdose crisis, a group that in...  The New York Times
# 2858  To combat the overdose crisis, a group that in...  The New York Times
# 2859  To combat the overdose crisis, a group that in...  The New York Times
#
#                                                keywords  \
# 0     {name: subject, value: Movies, rank: 1, major:...
# 1     {name: subject, value: Movies, rank: 1, major:...
# 2     {name: subject, value: Movies, rank: 1, major:...
# 3     {name: subject, value: Movies, rank: 1, major:...
# 4     {name: subject, value: Movies, rank: 1, major:...
# ...                                                 ...
# 2855  {name: subject, value: Documentary Films and P...
# 2856  {name: subject, value: Documentary Films and P...
# 2857  {name: subject, value: Documentary Films and P...
# 2858  {name: subject, value: Documentary Films and P...
# 2859  {name: subject, value: Documentary Films and P...
#
#                       pub_date  word_count  \
# 0     2023-05-25T11:00:03+0000         295
# 1     2023-05-25T11:00:03+0000         295
# 2     2023-05-25T11:00:03+0000         295
# 3     2023-05-25T11:00:03+0000         295
# 4     2023-05-25T11:00:03+0000         295
# ...                        ...         ...
# 2855  2023-02-02T12:00:11+0000         306
# 2856  2023-02-02T12:00:11+0000         306
# 2857  2023-02-02T12:00:11+0000         306
# 2858  2023-02-02T12:00:11+0000         306
# 2859  2023-02-02T12:00:11+0000         306
#
#                                           headline.main headline.kicker  \
# 0           ‘The Attachment Diaries’ Review: Love, Sick            None
# 1           ‘The Attachment Diaries’ Review: Love, Sick            None
# 2           ‘The Attachment Diaries’ Review: Love, Sick            None
# 3           ‘The Attachment Diaries’ Review: Love, Sick            None
# 4           ‘The Attachment Diaries’ Review: Love, Sick            None
# ...                                                 ...             ...
# 2855  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2856  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2857  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2858  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
# 2859  ‘Love in the Time of Fentanyl’ Review: Heartbr...            None
#
#      headline.content_kicker       headline.print_headline  ...  \
# 0                       None        The Attachment Diaries  ...
# 1                       None        The Attachment Diaries  ...
# 2                       None        The Attachment Diaries  ...
# 3                       None        The Attachment Diaries  ...
# 4                       None        The Attachment Diaries  ...
# ...                      ...                           ...  ...
# 2855                    None  Love in the Time Of Fentanyl  ...
# 2856                    None  Love in the Time Of Fentanyl  ...
# 2857                    None  Love in the Time Of Fentanyl  ...
# 2858                    None  Love in the Time Of Fentanyl  ...
# 2859                    None  Love in the Time Of Fentanyl  ...
#
#                                                overview popularity runtime  \
# 0     Argentina, 1970s. A desperate young woman goes...      5.643   102.0
# 1     Argentina, 1970s. A desperate young woman goes...      5.643   102.0
# 2     Argentina, 1970s. A desperate young woman goes...      5.643   102.0
# 3     Argentina, 1970s. A desperate young woman goes...      5.643   102.0
# 4     Argentina, 1970s. A desperate young woman goes...      5.643   102.0
# ...                                                 ...        ...     ...
# 2855  An intimate portrait of a community fighting t...      1.400    85.0
# 2856  An intimate portrait of a community fighting t...      1.400    85.0
# 2857  An intimate portrait of a community fighting t...      1.400    85.0
# 2858  An intimate portrait of a community fighting t...      1.400    85.0
# 2859  An intimate portrait of a community fighting t...      1.400    85.0
#
#      revenue release_date vote_average vote_count  \
# 0        0.0   2021-10-07          3.0        4.0
# 1        0.0   2021-10-07          3.0        4.0
# 2        0.0   2021-10-07          3.0        4.0
# 3        0.0   2021-10-07          3.0        4.0
# 4        0.0   2021-10-07          3.0        4.0
# ...      ...          ...          ...        ...
# 2855     0.0   2023-02-03          0.0        0.0
# 2856     0.0   2023-02-03          0.0        0.0
# 2857     0.0   2023-02-03          0.0        0.0
# 2858     0.0   2023-02-03          0.0        0.0
# 2859     0.0   2023-02-03          0.0        0.0
#
#                                 genres  spoken_languages  \
# 0     Drama, Mystery, Thriller, Horror           Spanish
# 1     Drama, Mystery, Thriller, Horror           Spanish
# 2     Drama, Mystery, Thriller, Horror           Spanish
# 3     Drama, Mystery, Thriller, Horror           Spanish
# 4     Drama, Mystery, Thriller, Horror           Spanish
# ...                                ...               ...
# 2855                       Documentary           English
# 2856                       Documentary           English
# 2857                       Documentary           English
# 2858                       Documentary           English
# 2859                       Documentary           English
#
#                   production_countries
# 0                            Argentina
# 1                            Argentina
# 2                            Argentina
# 3                            Argentina
# 4                            Argentina
# ...                                ...
# 2855  Canada, United States of America
# 2856  Canada, United States of America
# 2857  Canada, United States of America
# 2858  Canada, United States of America
# 2859  Canada, United States of America
#
# [2860 rows x 31 columns]
# C:\Users\sebas\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   from ipykernel import kernelapp as app

# %%
# Drop "byline.person" column
columns_to_drop = [col for col in merged_df.columns if 'byline.person' in col]
merged_df.drop(columns_to_drop, axis=1, inplace=True)

# %%
# Delete duplicate rows and reset index
merged_df.drop_duplicates(inplace=True)
merged_df.reset_index(drop=True, inplace=True)

# %%
# Export data to CSV without the index
merged_df.to_csv('merged_data.csv', index=False)

# %%
print(merged_df.columns)
# Out:
# Index(['web_url', 'snippet', 'source', 'keywords', 'pub_date', 'word_count',
#        'headline.main', 'headline.kicker', 'headline.content_kicker',
#        'headline.print_headline', 'headline.name', 'headline.seo',
#        'headline.sub', 'byline.original', 'byline.organization', 'title',
#        'original_title', 'budget', 'original_language', 'homepage', 'overview',
#        'popularity', 'runtime', 'revenue', 'release_date', 'vote_average',
#        'vote_count', 'genres', 'spoken_languages', 'production_countries'],
#       dtype='object')
